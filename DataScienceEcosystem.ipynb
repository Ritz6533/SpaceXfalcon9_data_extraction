# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# # Data science languages
#
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. Julia
# 4. Scala
# 5. JavaScript
# 6.  Swift
# 7. PHP
# 8. Go
# 9. Ruby

# %% [markdown]
# # Data science libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. SciKit-Learn
# 6. Apache Spark
# 7. Vegas
# 8. Big DL
# 9. Ggplot2

# %% [markdown]
# # Data Science tools
#
# These are some data science tools
#
# | Data Science tools |
# |--------------------|
# | Jupyter Notebook |
# | Docker |
# | PowerBI |
# | GitHub |
# | Tableau |
# | Spyder |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
#
# - Addition(+)
# - Subtraction(-)
# - Multiplication(*)
# - Division(/)

# %%
#this a simple arithmetic expression to mutiply then add integers. 

X= (3*4)+5
print("Answer =",X)
# Out:
# Answer = 17

# %%
#This will convert 200 minutes to  hours by diving by 60.

Minutes= 200
Hours= Minutes/60

print(f"the {Minutes} minutes is equal to {Hours} Hours")
# Out:
# the 200 minutes is equal to 3.3333333333333335 Hours

# %% [markdown]
# **Objectives**
#
# - List popular languages for Data Science
# - Create an table of data science tools.
# - Perform arithmetic calculations in Python.
# - Convert units in Python.

# %% [markdown]
# ## Author
# Ritesh Jung Shah
