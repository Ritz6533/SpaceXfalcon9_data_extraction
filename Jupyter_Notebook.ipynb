# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # The Practic Notebook(Title)
#
# My Practic Notebook (2023)

# %% [markdown]
# # Introduction
#
# Hello, This is my practice notebook.

# %% [markdown]
# # Data science languages
#
# There are many languages for data science and my favourite is Python.

# %% [markdown]
# # Data science libraries
#
# TensorFlow TensorFlow TensorFlow TensorFlow TensorFlow

# %% [markdown]
# # Data Science tools
#
# Tableau Tableau Tableau Tableau Tableau Tableau Tableau

# %% [markdown]
# # Arithmetic expression examples
#
# Addition(+) Subtraction(-) Multiplication(*) Division(/)

# %%
# multiply and addition
Num1=25
Num2=30

Multiplication= Num1*Num2
Addition= Num1+Num2

print("Multiplication =",Multiplication)
print("Addition =",Addition)
# Out:
# Multiplication = 750
# Addition = 55

# %%
#convert minutes to hours
Minutes= 120
Hours= Minutes/60
print("Minutes in hours = ",Hours)
print(f"the {Minutes} is equal to {Hours} Hours")
# Out:
# Minutes in hours =  2.0
# the 120 is equal to 2.0 Hours

# %% [markdown]
# # Objects
#
# object 1
# object 2
# object 3

# %% [markdown]
# # Author’s name
#
# Ritesh Jung Shah
